# %% [markdown]
# # Priprava podatkov

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("output_most_citations.xlsx")
df.head()
# Out:
#   Publication Type                                            Authors  \
# 0                J                  Jang, Y; Choi, S; Jung, H; Kim, H
# 1                J        Fahd, K; Venkatraman, S; Miah, SJ; Ahmed, K
# 2                J                  Bertolini, R; Finch, SJ; Nehm, RH
# 3                J  Puyana-Romero, V; Larrea-Alvarez, CM; Díaz-Már...
# 4                J   Abdelkader, HE; Gad, AG; Abohany, AA; Sorour, SE
#
#    Book Authors  Book Editors  Book Group Authors  \
# 0           NaN           NaN                 NaN
# 1           NaN           NaN                 NaN
# 2           NaN           NaN                 NaN
# 3           NaN           NaN                 NaN
# 4           NaN           NaN                 NaN
#
#                                    Author Full Names  Book Author Full Names  \
# 0  Jang, Yeonju; Choi, Seongyune; Jung, Heeseok; ...                     NaN
# 1  Fahd, Kiran; Venkatraman, Sitalakshmi; Miah, S...                     NaN
# ...

# %%
df = df[["Author Full Names", "Article Title", "Source Title", "Cited Reference Count"]]

# %%
df.to_excel("pmozni.xlsx", index=False)
